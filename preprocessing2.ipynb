# %%
import pandas as pd

# %%
file_path = './txt/topikI.csv'
tp = pd.read_csv(file_path, usecols=['등급', '어휘', '품사', '길잡이말'])
tp
tpDF = tp[:1300]

# %%
# 어휘에 중복값이 있는지 확인 => 데이터 오타有 명01 -> 병0로 판단. 수정.
print(tp['어휘'].duplicated().sum())
# Out:
# 0

# %%
th1 = ['ร้านค้า', 'ราคา', 'เฟอร์นิเจอร์', 'ใกล้', 'ไป', 'สอน', 'กระเป๋า', 'เบา', 'นักร้อง', 'เพลง', 'กลาง', 'ฤดูใบไม้ร่วง', 'ที่สุด', 'ครอบครัว', 'ชนิด', 'มี', 'ซี่โครง', 'ซุปซี่โครง, คัลบีทัง', 'ต่อรถ', 'ลูกพลับ', 'หวัด', 'ความขอบคุณ', 'ราคา', 'เหมือนกัน', 'ด้วยกัน', 'สุนัข', 'อัน', 'ที่นั่น', 'ห้องนั่งเล่น', 'สุขภาพ', 'ฝั่งตรงข้าม', 'ตึก, อาคาร', 'เดิน', 'แขวน']
print(len(th1))

# 하드코딩으로 1급 어휘 번역.
jp1 = ['店', '価格(=값)', '家具','近い','行く','教える','鞄','軽い','歌手', '歌謡、歌', '中','秋','一番、最も','家族','種類','持つ','カルビ','カルビタン','乗り換える','柿','風邪','感謝','値段','同じだ','一緒に','犬','個','そこ','居間', '健康', '向こう側','建物','歩く','掛ける','掛かる','もの','ゲーム','冬','ずっと','いらっしゃる','季節', '計画', '肉','選ぶ','ありがたい','猫','（お腹が）空く','故郷','ところ','勉強','公園','ノート','空港','果物','大丈夫だ','教室','交通','九','見物','靴','九十','九月','国籍','冊','耳','みかん','その','それ','そう','それで','だから','では','どころで','じゃ','それじゃ','そうだ','だが、だけど','皿','そして','描く','絵','一昨日','そちら、そっち','劇場','近く','文、文章','そうですね','金曜日','期間','待つ','気持ち','嬉しい','寮','汽車','道', '長い', 'キンパ、キムパプ（韓国式海苔巻き）','キムチ','キムチチゲ','きれいだ','ぜひ','花','消す','終わる']
jp2 = ['私、僕', '出ていく', '出る', '国','木', '悪い', '出てくる', '（時間や順序が）後','日', '天気', '日にち、日付', '南大門（ナムデムン）','弟', '南山（ナムサン）', '男', '旦那、夫','昼', '低い', '私の、僕の', '来年','降る', '明日', '冷麺', '君（きみ）、お前','とても、あまりにも', '広い', '入れる', '四','はい', '四', '年', '歌','カラオケ', '遊ぶ', 'バスケットボール', '高い','誰', 'お姉さん、姉（弟から見て）', '目', '雪','ニュース', '遅い、遅れる']
jp3 = ['全部', '行ってくる','通う', '違う、異なる','別の、違う～','足','五','また、再び','次、あと','単語', '閉める', '月（がつ）','甘い','タバコ','答え','大使館', '大学','大学校','大学生', '会話', 'もっと、もう','暑い', '図書館', '手伝う、助けてあげる', '到着','ドイツ', 'お金', '回る', '帰ってくる','手伝う、助ける', '東大門（ドンデムン）', '妹、弟', '間','なる', 'テンジャンチゲ、味噌鍋', '二つの、二', '二つ','後ろ', 'ドラマ', '差し上げる', '聞く','（お金などが）掛かる', '（カバンなどを）持つ', '入っていく、入る', '入ってくる、入る','山登り、登山', '暖かい', '娘', 'イチゴ','～とき', 'トッポッキ', 'また', 'ラーメン','ロシア', '匹', '飲む', '心','四十', '万', '会う', '作る','多い', 'たくさん','言葉、話','（動詞などについて）ない', 'マレイシア', 'お言葉', '清い', '味','まずい', 'おいしい', '合っている、正しい', '毎日','辛い', '頭', '食べる', '先に','遠い', 'かっこいい', 'メニュー', '何日','～人、～名', 'いくつ', 'すべて', '明後日','わからない、知らない', '帽子', '首', '木曜日','お風呂', '体', '～ことができない', '～ができない','モンゴル', '重い', '何（＋名詞）', '何','扉、ドア', '文化', '（わからないことを）聞く', '水','もの', '何（무엇の略語）', 'アメリカ', 'ごめん','美容室、ヘアサロン', '下']
jp4 = ['変える','バナナ','海','風','すぐに','忙しい','ズボン','博物館','外','半','クラス','（久しぶりに会えて）嬉しい','もらう','足','夜', 'ご飯', '部屋','休み','お腹','船','梨','俳優、女優','習う','百','百万','デパート','バス','番', '番号', 'ベトナム', 'あまり', '病気', '瓶','病院', '送る', '見る', '（比較）～より', '普通', 'ボールペン', '春', '呼ぶ', '両親','釜山（プサン）','キッチン、台所','お願い、頼み','方（人の尊敬語）','（時間の）～分','火','焼肉、ブルゴギ', '（風邪などが）吹く', '雨', 'ビビンバ', '（値段が）高い', '飛行機', '借りる', '速い、早い', '速く、早く', 'パン', '四','リンゴ','付き合う、友達になる','買う','人','恋、愛','オフィス、事務室','四十', '使用','四月','間、隙間','サイダー','辞書','写真','山','散歩','（年を数える時の）歳','生きる', '三','参鶏湯（サンゲタン）','三十','三月','思い、考え','お誕生日（尊敬語）','誕生日','生活','シャワー','三十（数えるときの）','ソウル','書店','プレゼント','先生', '説明','～歳（年を数えるとき使う）','洗顔','三','紹介','塩','手','客','ショッピング','スイカ','授業','水泳','プール','水曜日','手帳','宿題','お酒','休む','易い','スーパーマーケット','二十','スキー','悲しい','（時間を表すとき）～時','時間', '酸っぱい','涼しい','十月','始まり','市場','市役所','させる、注文する','試験、テスト','食堂、レストラン','食事','（靴などを）履く','新聞', '履物、靴', '失礼','嫌だ','嫌いだ','十', '十万', '十二月', '十一月', '（味が）薄い', '（値段が）安い', '書く', '使う', '苦い', '（人を呼ぶとき）～さん', '洗う', 'あ', '赤ちゃん', '妻', '違う（事実ではないこと）', 'いいえ', '下（밑の同義語）', 'アルバイト','美しい','お父さん','子供','アイスクリーム','おじさん','とても','おばさん','まだ','朝','アパート','痛い','九','九十','中','（形容詞や動詞の前につけて否定する文法）ない','眼鏡','案内','（挨拶）おはよう、こんにちは、こんばんは','さようなら','座る', '（知らなかったことを）知る','知らせる','前','野球','約～','薬','薬局','約束','どの','どこ', 'どんな', 'どうだ', '難しい', 'お母さん', '早く', '昨日', '億' ,'お姉さん、姉','いつ','顔','いくら','どんなに','（ものが）ない','エアコン','パスポート','ここ','八','妹','八十','いくつの、多くの','皆さん','夏','もしもし','六','女','旅行','旅行会社','駅','演劇','練習','鉛筆','十（=십）','開く','鍵','熱心に','ゼロ','イギリス','英語','映画','映画館','映画俳優','横','はい','きれいだ','五','今日','来る','オレンジ']
jp5 = ['右側', 'お兄さん、兄', '五十', '五月', '午前', '午後', '上がる、登る', '今年', '服', 'わ','なぜ、どうして','外国','外国語','外国人','左側','料理','曜日','最近','私たち、我々','傘','牛乳','郵便局','切手','運動','運動場','スニーカー','運転','泣く','笑う','ウォン（韓国の貨幣単位）', '～月（がつ）', '月曜日','上','有名','六月','六','六十','銀行', 'うむ','飲み物','食べ物', '音楽', '医者', '椅子', 'この', '二', 'これ', 'あとで', '名前', 'こん～、今回', '二十', '話', '二月', '理由', 'こっち', 'インドネシア', '～人前', '挨拶', '仁川（インチョン）', 'インターネット', '仕事', '一', '～日（にち）', '七', '日本', '起きる、起こる', '日曜日', '一月', '一周', '早く', '七十', '読む', '口', '着る', 'ある、いる', '寝る', '自動車、車', '自転車', '（頻度）よく', '去年', '小さい', '～杯', 'よく', '間違い', 'うまい、上手だ', '睡眠、寝ること', 'ちょっと、しばらく（＝잠시, 短い時間）', '少し、しばらく（＝잠깐, 短い時間）', '召し上がる', 'チャプチェ','場所','面白くない','面白い','あの','あの','あのう', 'あれ','あそこ','夕方','あっち、あちら', '少ない','元～','専攻','電話','電話番号','お昼','（バス）停','本当に', '私の', '一番', '済州島（チェジュド）','（量）ちょっと、少し','静かだ','卒業','ちょっと、少し', '従業員', 'いい','好きだ','申し訳ない','週','あげる','主に','週末','お休みになる','主婦','住所','ジュース','主人','～週日','準備','～中','中国','財布','今','過ぎる','先月','先週','昨年（=작년）','過ごす','消しゴム','地下鉄','地下鉄の駅','職業','職員','質問','家','しょっぱい、塩辛い','～側','（判子を）押す','本当に(=진짜)','ウリ','窓','探す','探してみる','本','机','初め','千','千万','ゆっくり','掃除','招待','チョコレート','踊る','サッカー','祝賀','出発','踊り、ダンス','踊りを踊る','寒い','趣味','～階','打つ','スカート','友達','親切','親しい','七','七十','七月','黒板','ベッド','カード','カメラ','カナダ','コーヒー','コーヒーショップ','コンピューター','コップ','ケーキ','（火、電気などを）つける','鼻','コンサート','コーラー','大きい、（背が）高い','背','燃える','乗る','卓球','タイ','テコンドー','タクシー','ターミナル','テニス','テレビ','土曜日','退勤','特別だ','特に','Ｔシャツ','パーティー','腕','八','売る','八十','八月','コンビニ','手紙','ブドウ','チケット','フランス','プログラム','疲れ','ピアノ','咲かせる','必要','筆箱','一つ','する','一日','下宿屋','だけど','学校','学生','学生証','一～','暇だ','韓国','ハンボク、チマチョゴリ','おばあさん','おじいさん','一緒に(=같이)','お兄さん','～号','ホテル','一人','火曜日','トイレ','会社','会社員','会議','～後','休暇','曇る','疲れる、しんどい'] #''
jp_1=jp1+jp2+jp3+jp4+jp5
len(jp_1)
# Out:
# 34
# 735

# %%
jp21 = ['近く','たまに','細い','いっぱい','指す','胸','ハサミ','持っていく','持ってくる','各、おのおの','簡単だ','簡単に','おやつ','醤油','ナース、看護師','茶色','着替える','風邪薬','（目を）瞑る、閉じる','（髪を）洗う','ジャガイモ','急に、いきなり','川','子犬','強い','持つ','（お金などを）返す','～ヶ月','～もの','街','距離','鏡','ほとんど、ほぼ','拒絶','ウソ','心配','渡っていく、横切る','渡る','歩いていく','歩いてくる','歩み','検査','黒色','黒','表','怠ける','結果','欠席','決心','決定','結婚','結婚式','競技','警察','警察署','景色','経験','階段','卵','計算','頭','高校','高校生','おばさん（父側の女の兄弟）','悩み','高速バス','故障','コチュジャン','直す','すぐ','ボール','公務員','工場','ただ、無料','祝日','過去','お菓子','関係','観光','観光客','観光地','関心','広告','光州','教科書','教師','教授','教育','交通費','交通事故','交換','協会','雲','汁','国内','麺','国際','軍人','太い','焼く', '知りたい、気になる', 'ピアス', '可愛がる', '可愛い', 'めんどくさい', '規則、ルール', 'それ','そこ','その日','ただ','そのまま','その間','その時','だが','その故','そんな','懐かしい','それくらいにして','止める、辞める','その方','止む','さあ','字','文字','すぐ(=곧)', '禁止', '急ぐ', '飼う', '油', '喜ぶ', '喜び', '記憶', '思いつく', '気温', '記者', '汽車の駅', '汽車のチケット', '咳', 'ギター', '機会', '緊張', '長さ', 'のり', '深い', '深く', '黒い色', '黒い', '削る、（皮を）むく、剃る', 'びっくり', 'きれいに', '覚ます', '（鞄などからものを）出す', 'ガム', '花束', '花瓶','花屋', '（夢を）みる', '夢', '止める、絶つ', '沸く', '沸かす、煮る','終わり、末','終える、済ませる','差し込む','分ける','余り','歳','現れる','四日（間）','釣り','飛ぶ','すらりとしている','他人、人', '残す','男女', '残る', '男性', '南側', '男子学生', '（～の方が）いい', '治る', '昼寝', '内科', '（問題を）出す', '降りていく、下がる', '降りてくる、下げる', '内容', '鍋', '匂い', '冷蔵庫', '君たち', '超える', '倒れる', '四～', 'ネクタイ', '四番目', '黄色', '黄色い', '努力', '老人', 'ノート', '緑色', '緑茶', '驚く', '遊び', '冗談', '高さ', '高く', '置く', '押す', '涙', '横になる', '感じる', '感じ', '遅い', 'いつも', '増える', '老いる', '能力']
jp22 = ['橋', '五番目', 'いろんな、様々な、多様な', '次の日', 'ダイエット', 'けがをする', '尽きる', '磨く', '単純', 'ボタン', '紅葉', '卵（=계란)', 'カレンダー', '走り', '走る', '鶏', '鶏肉', '似る', '答え', '返事', 'もどかしい', '～台', '大邱', 'ほとんど(=거의)', '大田（テジョン）', '大学院', '大会', 'お宅', '汚い', 'もっと', 'おかげ', '投げる', '連れていく', '連れてくる', 'デート', '～度', '道路','都市', '助け', '読書', '豚カツ', '石', '回る', '返す', '回す', '町内', '動物', '動物園', '同時', 'コイン', '東側', '豚', '豚肉', '～される、～になる', '味噌', '厚い', '置く', '豆腐', '二三', '頭痛', '二番目', '後ろ側', 'ついに、いよいよ', '寄る', '聞こえる', '背中', 'デザイン', '別々', '汗', '地', '離れる', '騒ぐ', '餅', 'トック', '落ちる', 'または', 'そっくりだ、まったく同じだ', '同じく', '頭がいい', 'まっすぐ', '太っている', '走る、駆ける','駆けていく','熱い','（目を）開く','意味','ラジオ','レストラン','庭','渇く','村','出迎え','最後','終わる、終える','マート','マッコリ','塞がる','餃子','もしも','万が一','触る','漫画','馬','末','合わせる','毎年','結ぶ、締める','毎月','とても','毎週','切符売り場','ビール','髪の毛','遠く','止まる','おしゃれ','担ぐ、背負う','メモ','メッセージ','メール','年中行事','蚊','全ての','姿','仕える、お供する','模様','集める','集まる','集まり','集会','足りない','ネックレス','声','お風呂','目的','不細工だ','大根','重さ','むくげの花','無料','怖い','膝','とても（=무척）','問題','魚','もちろん','聞いてみる','滑る','未来','事前に','美術館','わかめスープ','メーター','信じる','小麦粉','（ドアなどを）押す','外（≒밖）','外側','変わる','床','海辺','望む','眺める','塗る','バイオリン','拍手','反対','必ず','半ズボン','指輪','おかず','書き取り','足指','足裏','明るい','只今','部屋のドア','訪問','方法','放送','放送局','方向','～倍','配達','バドミントン', '白菜', '腹痛', '蛇','癖','捨てる', '～番目', '（服を数える単位）～着', '稼ぐ', 'もう', '脱ぐ', '壁', '変わる（≒바뀌다）', '弁護士', '星', 'お見舞い', '紫色', '見える', '見せる', '復習', '複雑だ', '炒める', '炒飯（チャーハン）', '封筒', 'お目にかかる', '恥ずかしい', 'やわらかい', 'うらやましい', '（お腹が）いっぱいになる', '夫婦', '部分', '奥さん（≒아내）', 'お金持ち', '部長', '不足', '勤勉だ', '送る', '北側', '確かだ', '粉食（トッポキやキンパなどのこと）','雰囲気', 'ピンク色','哀れだ','不安','不便','赤い','くっつく','貼る','ブラウス','比較','ソープ','（席などが）空く','ビデオ','秘密','似ている','ビル','落ちる','赤色','赤い','洗う、洗濯する','洗濯物','パン屋','(≒뽑다)抜く、引く, 外す', '(≒빼다)抜く','四つ角','四季','事故','事実','事業','サイズ','社長','飴']
jp23 = ['3日間', '肉（人間や動物の体で骨を囲む柔らかい）', '三つ角', 'サムギョプサル', '叔父', '賞', '箱', '傷、けが', 'レタス、チシャ', '商品', '鳥', '新しい', '新しく','新しい','夜明け','新年','色(≒색깔)','色（≒색）','サンドイッチ','思い出す','（物が）できる、生じる','魚（料理）','三四～','立つ','急ぐ','引き出し','お互い','書類','サービス', '西洋', '西側', '混ぜる', '先輩', '涼しい', '選手', '洗濯', '扇風機', '皿洗い', '（旧正月の）元旦', 'ソルロンタン', '砂糖', '島', '寂しい', '姓、苗字', '性格', '成功','成績','お名前（이름の尊敬語）','～歳','世界','強い','セベ（お正月に目上の人に対するあいさつとして行うお辞儀）','世界、世','建てる','洗濯','洗濯機','クリーニング屋','センター','センチメートル','三番目','牛','牛肉','音','小説','便り、消息','焼酎','大事だ','ソファー','小包','ピクニック','消化剤','中（≒안）','速度','下着','指','孫娘','手のひら','ハンカチ','ソンピョン(松餅)', '数', 'タオル', 'ご苦労', '手術', '水着', '橋とスプーン', 'スンドゥブチゲ', '順番', 'スプーン', '居酒屋', '数字']

jp_2=jp21+jp22+jp23
len(jp_2)
# Out:
# 565

# %%
jp_12=jp_1+jp_2
len(jp_12)
# Out:
# 1300

# %%
tpDF['jp'] = jp_12
tpDF
# Out:
# C:\Users\KDP-48\AppData\Local\Temp\ipykernel_3548\2458586964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tpDF['jp'] = jp_12
#       등급     어휘   품사        길잡이말       jp
# 0     1급     가게   명사      가게에 가다        店
# 1     1급   가격02   명사     가격이 비싸다   価格(=값)
# 2     1급   가구02   명사      가구를 놓다       家具
# 3     1급    가깝다  형용사     거리가 가깝다       近い
# 4     1급   가다01   동사      학교에 가다       行く
# ...   ..    ...  ...         ...      ...
# 1295  2급  순두부찌개   명사  순두부찌개를 끓이다  スンドゥブチゲ
# 1296  2급     순서   명사     순서를 매기다       順番
# 1297  2급    숟가락   명사     숟가락을 들다     スプーン
# 1298  2급     술집   명사       술집 출입      居酒屋
# 1299  2급     숫자   명사      숫자를 세다       数字
#
# [1300 rows x 5 columns]

# %%
#tpDF.to_csv('./txt/topikI_jp')
